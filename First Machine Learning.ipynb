# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("/home/saikantareddy/Desktop/insurance.csv")

# %%
df
# Out:
#     number of claims  amount paid
# 0                108        392.5
# 1                 19         46.2
# 2                 13         15.7
# 3                124        422.2
# 4                 40        119.4
# 5                 57        170.9
# 6                 23         56.9
# 7                 14         77.5
# 8                 45        214.0
# 9                 10         65.3
# 10                 5         20.9
# 11                48        248.1
# 12                11         23.5
# 13                23         39.6
# 14                 7         48.8
# 15                 2          6.6
# 16                24        134.9
# 17                 6         50.9
# 18                 3          4.4
# 19                23        113.0
# 20                 6         14.8
# 21                 9         48.7
# 22                 9         52.1
# 23                 3         13.2
# 24                29        103.9
# 25                 7         77.5
# ...

# %%
plt.scatter(df['number of claims'].values,df['amount paid'].values)
plt.xlabel("number of claims")
plt.ylabel("amount paid")
plt.show()

# %%
X=df['number of claims'].values.reshape(63,1)
Y=df['amount paid'].values
print(X.ndim)
print(Y.ndim)
# Out:
# 2
# 1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingClassifier

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=0)
print(X_train).ndim
print(X_test).ndim
print(y_train).ndim
print((y_test)).ndim
# Out:
# 2
# 2
# 1
# 1

# %%
#model=LinearRegression()
#model=LogisticRegression()
#model=GaussianNB()
#model=SVC()
#model=LinearSVC()
#model=Perceptron()
#model=DecisionTreeClassifier()
#model=RandomForestClassifier()
#model=KNeighborsClassifier()
#model=SGDClassifier()
model=GradientBoostingClassifier()
y_train=y_train.astype('int')
print(model.fit(X_train,y_train))
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
predictions=model.predict(X_test)
(predictions).reshape(1,-1)
# Out:
# array([[181,  13,  69,  89,  50, 113,  12,  57, 214,  89,  12,  77, 181,
#          12,  46,  12]])

# %%
sb.distplot(y_test-predictions)
x=y_test.reshape(-1,1)
model.score(x,predictions)
#round(model.score(x, predictions) * 100,2)
# Out:
# 0.0

# %%
 myvals = np.array([2]).reshape(1,-1)
 model.predict(myvals)
# Out:
# array([6])
